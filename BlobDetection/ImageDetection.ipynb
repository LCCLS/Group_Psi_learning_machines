# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
im = cv2.imread("test_pictures.png", cv2.IMREAD_COLOR)
im = im[:,:,::-1]

# %%
im = cv2.imread("test_pictures.png", cv2.IMREAD_COLOR)
im = im[:,:,::-1]
im = append_white_column_left_and_right(im)

# %%
im.shape
# Out:
# (640, 480, 3)

# %%
plt.imshow(im)
plt.show()

# %%
LOWER_GREEN = np.array([15, 80, 0], dtype = "uint8")
UPPER_GREEN = np.array([85, 255, 75], dtype = "uint8")

# %%
def append_white_column_left_and_right(image):
    image = np.insert(image, 0, 255, axis=1)
    image = np.insert(image, image.shape[1], 255, axis=1)
    return image

# %%
splitted_image = np.hsplit(im, 5)
detected = []
for idx, image_part in enumerate(splitted_image):
    mask = cv2.inRange(image_part, LOWER_GREEN, UPPER_GREEN)
    print(np.count_nonzero(mask))
    has_green = np.count_nonzero(mask) > 150
    detected.append(has_green)
    keypoints = detector.detect(image_part)
    # detected.append(len(keypoints) > 0)
    if True:
        im_with_keypoints = cv2.drawKeypoints(image_part, keypoints, np.array([]), (0, 0, 255),
                                              cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        plt.subplot(1, 5, idx+1)
        plt.imshow(im_with_keypoints)
        plt.plot()
plt.show()
joined_string = "   "
joined_string = joined_string + '    '.join([str(v) for v in detected])
print(joined_string)
# Out:
# 5
# 0
# 1271
# 0
# 351
#    False    False    True    False    True

# %%
splitted_image = np.hsplit(im, 5)
detected = []
for image_part in splitted_image:
    #image_part = append_white_column_left_and_right(image_part)
    #image_part = append_white_row_top_and_bottom(image_part)
    mask = cv2.inRange(image_part, LOWER_GREEN, UPPER_GREEN)
    has_green = np.any(mask)
    detected.append(has_green)
    keypoints = BlobDetector.detector.detect(image_part)
    # detected.append(len(keypoints) > 0)
    if FLAGS.pictures:
        im_with_keypoints = cv2.drawKeypoints(image_part, keypoints, np.array([]), (0, 0, 255),
                                              cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        plt.imshow(im_with_keypoints)
        plt.show()
detected
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 splitted_image = np.hsplit(im, 5)
#       2 detected = []
#       3 for image_part in splitted_image:
#       4     #image_part = append_white_column_left_and_right(image_part)
#       5     #image_part = append_white_row_top_and_bottom(image_part)
#
# File <__array_function__ internals>:180, in hsplit(*args, **kwargs)
#
# File /opt/anaconda3/envs/LM/lib/python3.10/site-packages/numpy/lib/shape_base.py:940, in hsplit(ary, indices_or_sections)
#     938     raise ValueError('hsplit only works on arrays of 1 or more dimensions')
#     939 if ary.ndim > 1:
# --> 940     return split(ary, indices_or_sections, 1)
#     941 else:
#     942     return split(ary, indices_or_sections, 0)
#
# File <__array_function__ internals>:180, in split(*args, **kwargs)
#
# File /opt/anaconda3/envs/LM/lib/python3.10/site-packages/numpy/lib/shape_base.py:872, in split(ary, indices_or_sections, axis)
#     870     N = ary.shape[axis]
#     871     if N % sections:
# --> 872         raise ValueError(
#     873             'array split does not result in an equal division') from None
#     874 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division
