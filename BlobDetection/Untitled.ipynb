# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

# Change thresholds
params.minThreshold = 10
params.maxThreshold = 200

# %%
im = cv2.imread("pictures/test_pictures_2.png", cv2.IMREAD_COLOR)

# %%
im.shape
# Out:
# (128, 128, 3)

# %%
detector = cv2.SimpleBlobDetector_create(params)
keypoints = detector.detect(im)
im_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
len(keypoints)
# Out:
# 1

# %%
plt.imshow(im_with_keypoints)
plt.show()

# %%
new_im = np.hsplit(im, 4)

# %%
plt.imshow(new_im[3])
plt.show()

# %%
part = new_im[3]

# %%
params = cv2.SimpleBlobDetector_Params()

# Change thresholds
#params.minThreshold = 10
#params.maxThreshold = 200

# Filter by Area.
#params.filterByArea = False
#params.filterByCircularity = False
params.filterByColor = True
#params.filterByConvexity = False
#params.filterByInertia = False

params.blobColor = 200

# %%
detector = cv2.SimpleBlobDetector_create(params)
keypoints = detector.detect(new_part)
im_with_keypoints_new = cv2.drawKeypoints(new_part, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
print(len(keypoints))
plt.imshow(im_with_keypoints_new)
plt.show()
# Out:
# 0

# %%
type(part)
# Out:
# numpy.ndarray

# %%
new_part = np.insert(part, 0, 255, axis=1)

# %%
new_part = np.insert(new_part, 33, 255, axis=1)

# %%
new_part = np.insert(new_part, 0, 255, axis=0)
new_part = np.insert(new_part, new_part.shape[0], 255, axis=0)
