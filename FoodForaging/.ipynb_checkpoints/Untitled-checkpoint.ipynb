# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread("red_food.png")

# %%
plt.imshow(image)
plt.show()

# %%
green = np.uint8([[[0,0,255 ]]])
hsv_green = cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
print( hsv_green )
# Out:
# [[[  0 255 255]]]

# %%
LOWER_RED_HSV = np.array([0, 100, 100], dtype = "uint8")
UPPER_RED_HSV = np.array([10, 255, 255], dtype = "uint8")
